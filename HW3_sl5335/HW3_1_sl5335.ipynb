# %% [markdown]
# # Written by Federica B. Bianco @fedhere
# # NYU CUSP PUI2016
# # Assignment 1 Homework 3
# # This is a skeleton & instruction notebook
# - ## GENERATE  100 samples of different sizes N (N>10 & N<2000) from each of 5 different distributions (500 samples in total),
# ## _all with the same population mean_. Include a _Normal_, a _Poisson_, a _Binomial_, a _Chi-Squared_ distribution, and 1 more of your choice.
# - ## For each sample plot the sample mean (dependent var.) against the sample size N (independent var.) (if you want you can do it with the sample standard deviation as well).
# - ## Describe the behavior you see in the plots in terms of the law of large numbers.
# - ## PLOT the distributions of all sample means (together for all distributions). _Mandatory_: as a histogram. _Optional_: in any other way you think is convincing
# ## Extra Credit: FIT a gaussian to the distribution of means

# %%
from __future__ import print_function
__author__= 'fbb'

import pylab as pl
# this package sets up pretty plots
# import seaborn
from scipy.optimize import curve_fit, minimize
    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## choose which distributions to use

# %%
#distributions = ['pois', 'gaus', 'chisq', 'cauchy', 'lnorm', 'binomial']
distributions = ['chisq']

# %% [markdown]
# ## and which mean to give it

# %%
mymean = 100

# %% [markdown]
# # Let's see what this distribution looks like, what is the PDF, and how are the moments defined. Wikipedia is great for this!
#
# ![1](chisq1.png)
#
# ![2](chisq2.png)

# %% [markdown]
# # Then lets look at the numpy random sampling package to see how I create the distribution
# http://docs.scipy.org/doc/numpy/reference/routines.random.html
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.chisquare.html#numpy.random.chisquare
#
# ![numpy](numpy_chisq.png)

# %%
# the chi sq distribution takes the number of degrees of freedom, which luckily is the same as the mean!
df = mymean

# %% [markdown]
# ## I am making a dictionary to host the distributions.
#
# that is only one possible option. with a dictionary I can easily inspect the distribution I want by its name: it is a very human friendly data storage. In this example I am only using a single distribution, so for me it is overkill, but if I were doing the whole exercise with 5 or 6 distributions it would be useful!
#
# Lets start by looking at a single chi sq distribution

# %%
# Note: I am adding imports here, to show the workflow: 
# at this point I realize what packages I need and I import them. 
# but this is a PEP8 violation. 
# It is a good habit to put the includes at the top 
# so the code fails right away if the packages are missing. 
# Otherwise a user may have a piece of code running for a long time, 
# and then fail when the package cannot be imported... 
# (unless they are only imported under conditions, e.g. in an if statement)

import numpy as np
md = {}
# md is an empty disctionary
md['chisq'] = np.random.chisquare(df, size=100)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ### Figure 1: Chi sq distribution: df = 100, N=100

# %% [markdown]
# ## let numpy calculate what the mean and stdev of this distribution are

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 103.11, standard deviation: 14.11

# %% [markdown]
# ## Now let's do it for 100 Chisq distributions
# we want distributions of different sizes (all integers between 10 and 2000)

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
# mysize = 1000 / (np.array(range(1, 100) + [10]))
# mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
# I am gonna overwrite the disctionary entry created into a nested dictionary 
# the outside dictionary hosts the distributions as dictionary, 
# and each distribution dictionary contains the 100 distribution (arrays of diferent sizes)

md['chisq'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)
    
# save the means for plotting later    

md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure 2:  100 Normally distributed chi-square means with df = 100, size with a minimum of 10 and a maximum of 2000

# %% [markdown]
# # now the histogram of the mean of all samples:
# ## this requires some data wrangling, since i put the data in a dictionary which is a user friendly data structure, but perhaps not the most machine friendly one
#
# a coder friendly, though not terribly pythonic way to do it is to append each mean in a list in a for loop, and then hist that. be careful: if your data size gets large this becomes a very bad idea!!

# %%
allmeans = list(md['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ### Figure 3: Normal distribution of 100 sample means for chi square distribution with df=100, size = 100.

# %% [markdown]
# # Do it for the Normal distribution

# %%
md['Normal'] = np.random.normal(loc = 100, size = 100)
# adding the array by the key 'Normal'
pl.hist(md['Normal'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ## Figure 4: Normal distribution with mean = 100, size = 100

# %%
print ("Normal mean: %.2f, standard deviation: %.2f"%(md['Normal'].mean(), md['Normal'].std()))
# Out:
# Normal mean: 99.94, standard deviation: 0.99

# %%
md['normal'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['normal'][n] = np.random.normal(loc = 100, size = n)
    
# save the means for plotting later    

md['normal']['means'] = {}
axnormal_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['normal']['means'][nn] = md['normal'][nn].mean()
        #and plot it
        axnormal_mu_n.plot(nn, md['normal']['means'][nn], 'o')
        axnormal_mu_n.set_xlabel('sample size', fontsize=18)
        axnormal_mu_n.set_ylabel('sample mean', fontsize=18)
        axnormal_mu_n.set_title('Normal', fontsize=18)
        axnormal_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure 5:  100 Normal distributions with population mean of 100 and size between 10 and 2000

# %%
allmeans = list(md['normal']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ### Figure 6: Histogram of the sample means of 100 normal distributions with population mean of 100 and sizes between 10-2000

# %% [markdown]
# # Do it for the Poisson distribution

# %%
md['poisson'] = np.random.poisson(lam = 100, size = 100)
# adding the poisson array
pl.hist(md['poisson'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ### Figure 7: Poisson distribution with lambda = 100, size = 100

# %%
print ("Poisson mean: %.2f, standard deviation: %.2f"%(md['poisson'].mean(), md['poisson'].std()))
# Out:
# Poisson mean: 100.83, standard deviation: 9.82

# %%
md['poisson'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['poisson'][n] = np.random.poisson(lam = 100, size = n)
    
# save the means for plotting later    

md['poisson']['means'] = {}
axpoisson_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['poisson']:
    if not type(nn) == str:
        md['poisson']['means'][nn] = md['poisson'][nn].mean()
        #and plot it
        axpoisson_mu_n.plot(nn, md['poisson']['means'][nn], 'o')
        axpoisson_mu_n.set_xlabel('sample size', fontsize=18)
        axpoisson_mu_n.set_ylabel('sample mean', fontsize=18)
        axpoisson_mu_n.set_title('Poisson', fontsize=18)
        axpoisson_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure 8 100 Poisson distributions with lambda = 100, size between 10 - 2000

# %%
allmeans = list(md['poisson']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ### Figure 9: Distribution of sample means for 100 poisson distributions with population mean of 100 and sample size 10-2000

# %% [markdown]
# # Do it for the Binomial distribution

# %%
md['binomial'] = np.random.binomial(200, .5, 100)
# adding the binomial array
pl.hist(md['binomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ### Figure 10: Binomial distribution for 200 trials with a 50% probability of success with size of 100.

# %%
print ("Binomial mean: %.2f, standard deviation: %.2f"%(md['binomial'].mean(), md['binomial'].std()))
# Out:
# Binomial mean: 100.27, standard deviation: 7.12

# %%
md['binomial'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['binomial'][n] = np.random.binomial(200, .5, size = n)
    
# save the means for plotting later    

md['binomial']['means'] = {}
axbinomial_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
        #and plot it
        axbinomial_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        axbinomial_mu_n.set_xlabel('sample size', fontsize=18)
        axbinomial_mu_n.set_ylabel('sample mean', fontsize=18)
        axbinomial_mu_n.set_title('Binomial', fontsize=18)
        axbinomial_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure 11: 100 Binomial distributions with 200 trials, probability of 50%, size between 10 - 2000

# %%
allmeans = list(md['binomial']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ### Figure 12: Distribution of sample means of 100 binomial distributions with 200 trials, 50% probabilty and size between 10-2000

# %% [markdown]
# # Do it for another distribution

# %%
md['exponential'] = np.random.exponential(100, size = 100)
# adding the exponential array
pl.hist(md['exponential'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# ### Figure 13: Exponential distribution with a population mean of 100 and size 100

# %%
print ("Exponential mean: %.2f, standard deviation: %.2f"%(md['exponential'].mean(), md['exponential'].std()))
# Out:
# Exponential mean: 97.41, standard deviation: 84.21

# %%
md['exponential'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['exponential'][n] = np.random.binomial(200, .5, size = n)
    
# save the means for plotting later    

md['exponential']['means'] = {}
axexponential_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['exponential']:
    if not type(nn) == str:
        md['exponential']['means'][nn] = md['exponential'][nn].mean()
        #and plot it
        axexponential_mu_n.plot(nn, md['exponential']['means'][nn], 'o')
        axexponential_mu_n.set_xlabel('sample size', fontsize=18)
        axexponential_mu_n.set_ylabel('sample mean', fontsize=18)
        axexponential_mu_n.set_title('Exponetial', fontsize=18)
        axexponential_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure 14: 100 Exponential distributions with population mean of 100 and size ranging from 10-2000

# %%
allmeans = list(md['binomial']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
#    ### Figure 15: Distribution of 100 exponential distributions with population mean of 100 and size of 100
